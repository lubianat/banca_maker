# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_escavador_page(name):
    try:
        search_url = "https://www.escavador.com/busca?qo=p&q=" + name
        page = requests.get(search_url)
        soup = BeautifulSoup(page.text, 'html.parser')
        # Pull all text from the BodyText div
        researcher_list = soup.find(class_="list-search")

        # Pull text from all instances of <a> tag within BodyText div
        researcher_list_items = researcher_list.find_all('a')

        escavador_url = researcher_list_items[2].get('href')
        
        return(escavador_url + "#academico")
    
    except:
        
        return("not found")

# %%
escavador_url = get_escavador_page('Tie Koide')

escavador_url

soup = BeautifulSoup(page.text, 'html.parser')
        # Pull all text from the BodyText div

escavador_url

# desisto
# Out:
# 'https://www.escavador.com/sobre/554437/tie-koide#academico'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="" dir="ltr" lang="pt-br">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8"/>
# <title>Resultados | Escavador</title>
# <meta content="https://www.escavador.com" name="base-url-site"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="pt_BR" property="og:locale">
# <meta content="https://www.escavador.com/busca" property="og:url">
# <meta content="Escavador" property="og:site_name">
# <meta content="website" property="og:type">
# <meta content="Resultados | Escavador" property="og:title"/>
# <meta content="https://www.escavador.com/assets/images/escavadeira.jpg" property="og:image"/>
# <meta content="295" property="og:image:width"/>
# <meta content="295" property="og:image:height"/>
# <meta content="942066845880479" property="fb:pages">
# ...

# %%
projetos

# %%
projetos

# %%
projetos

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="" dir="ltr" lang="pt-br">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8"/>
# <title>Resultados | Escavador</title>
# <meta content="https://www.escavador.com" name="base-url-site"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="pt_BR" property="og:locale">
# <meta content="https://www.escavador.com/busca" property="og:url">
# <meta content="Escavador" property="og:site_name">
# <meta content="website" property="og:type">
# <meta content="Resultados | Escavador" property="og:title"/>
# <meta content="https://www.escavador.com/assets/images/escavadeira.jpg" property="og:image"/>
# <meta content="295" property="og:image:width"/>
# <meta content="295" property="og:image:height"/>
# <meta content="942066845880479" property="fb:pages">
# ...
